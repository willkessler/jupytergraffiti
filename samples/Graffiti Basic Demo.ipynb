# %% [markdown]
# # Welcome to Jupyter Graffiti!
#
# What can Jupyter Graffiti do? You can:
#
# * Create movies to highlight what's important
# * Diagram and demonstrate complex concepts
# * Add interactive shells and buttons... and much more
#
# Try hovering over the equation of the Pythagorean Theorem below (with the green dashed underlines) to see how Graffiti works.
# <hr>

# %% [markdown]
# <div style=" font-size:32px;  line-height:42px;  padding-top:0px;  margin-left:10px;color:black">
#  The Pythagorean Theorem:
#  <span style="padding:15px;margin-top:50px;cursor:pointer"><span class="graffiti-highlight graffiti-id_9xf6oai-id_ymgzeho"><i></i>$c = \sqrt{a^2 + b^2}$</span></span>
# </div>
# <div style="background: url(./images/pythagoras3.png);color:white; background-opacity:0.5;  width:100%;  display:flex;  height: 250px;  margin-top:15px;display: block;  position: relative;">
#
# </div>

# %%
import math
def calculate_hypotenuse(a,b):
    c = math.sqrt(math.pow(a,2) + math.pow(b,2))
    return (c)

print (calculate_hypotenuse(3,4))

# %% [markdown]
# ### Graffiti Buttons, Shells, and Solutions

# %% [markdown]
# Let's see how a student might use a Graffiti to try to write some code, and how an instructor might show them a solution. Also, note the Graffiti tips explaining `main` and `cout`, without movies associated with them.

# %%
// Write a C++ program to find the sum of first 10 natural numbers.
#include <iostream>
using namespace std;
int main()
{
    int i, sum = 0;
    cout << "The sum of the first 10 natural numbers is: "<< sum << endl;
}

# %% [markdown]
# <i>Loading terminal (id_up4395w), please wait...</i>

# %% [markdown]
# <span class="graffiti-highlight graffiti-id_wqqrbuy-id_ji3jyas"><i></i><button>Run Code</button></span>
# <span class="graffiti-highlight graffiti-id_nnb8lvv-id_7wwa9gi"><i></i><button>Hide Solution</button></span>

# %%
#include <iostream>
using namespace std;
int main()
{
    int i,sum=0;
    cout << "\n\n Find the first 10 natural numbers:\n";
    cout << "---------------------------------------\n";
    cout << " The natural numbers are: \n";
    for (i = 1; i <= 10; i++) 
    {
        cout << i << " ";
        sum = sum + i;
    }
    cout << "\n The sum of first 10 natural numbers: "<<sum << endl;
}

# %% [markdown]
# ### Try it out yourself!

# %% [markdown]
# To get started creating your own Graffiti, click "Show Graffiti Editor" in the menu bar. Then select some text, for instance, some text in the code cell below, to get started on making recordings.  We've installed `nbzip` into Binder so that if you are trying this on binder, you can download the `jupytergraffiti_data` folder (at the same level as this notebook) in a tarball for later upload on another binder or for further publishing. This folder, along with this notebook, contains everything that you've recorded in Graffiti.

# %% [markdown]
# ![makeYourOwnGraffiti.png](attachment:makeYourOwnGraffiti.png)
#
# <div style="height:50px;">&nbsp;</div>

# %%
# Select some text in here to create your own Graffiti. 
# First you'll create a tip. Then you can create a recorded video.


# This code randomly select an item from a list
import random

foo = ['a', 'b', 'c', 'd', 'e']
random.choice(foo)

# %% [markdown]
# #### But how do I download the `jupytergraffiti_data` folder using `nbzip`?

# %% [markdown]
# Click the Jupyter logo to get to the top tree. Click into the `jupytergraffiti_data` folder. Then use the download link at the top right to download the entire folder.
